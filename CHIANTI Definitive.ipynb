# %%
import matplotlib.pyplot as plt
import numpy as np
import ChiantiPy.core as ch
import ChiantiPy.tools.filters as chfilters
# Out:
#  ChiantiPy version 0.11.0
#  found PyQt5 widgets
#  using PyQt5 widgets

# %%
import warnings   # ------ librería que esconde los warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # FLARE

# %%
si2 = ch.ion('si_2',temperature=31622.8,eDensity=1.e+14,em=2.e+30)
si2.intensityPlot(wvlRange=[1520.,1540.],linLog='lin')

# %%
si2.intensityList(wvlRange=[1520.,1540.])
# Out:
#  temperature =    3.16e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  si_2     1     8              3s2.3p 2P0.5 - 3s2.4s 2S0.5                 1526.7070     1.00e+04     3.82e+08 Y
#  si_2     2     8              3s2.3p 2P1.5 - 3s2.4s 2S0.5                 1533.4310     1.97e+04     7.54e+08 Y
#
#  ------------------------------------------

# %%
c4 = ch.ion('c_4',temperature=1.e+5,eDensity=1.e+14,em=5.e+28)

# %%
c4.intensityPlot(wvlRange=[1540.,1600.],linLog='lin')

# %%
c4.intensityList(wvlRange=[1540.,1560.])
# Out:
#  temperature =    1.00e+05 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_4    95   150        1s.2s(1S).3p 2P1.5 - 1s.2s(3S).4s 2S0.5           1540.6230     1.92e-18     1.62e+07 N
#   c_4   209   498        1s.2p(3P).4p 4P0.5 - 1s.2p(3P).6d 4D1.5           1544.7990     1.99e-19     6.57e+07 N
#   c_4   209   497        1s.2p(3P).4p 4P0.5 - 1s.2p(3P).6d 4D0.5           1544.9970     2.74e-19     1.17e+08 N
#   c_4   216   570        1s.2p(3P).4d 2D1.5 - 1s.2p(3P).6f 2D1.5           1545.2990     9.51e-19     4.12e+07 N
#   c_4   211   500        1s.2p(3P).4p 4P2.5 - 1s.2p(3P).6d 4D3.5           1545.7440     1.84e-18     1.32e+08 N
#   c_4   217   569        1s.2p(3P).4d 2D2.5 - 1s.2p(3P).6f 2D2.5           1547.2590     1.88e-18     4.64e+07 N
# ...

# %%
c1 = ch.ion('c_1',temperature=15848.0,eDensity=1.e+14,em=2.e+31)
c1.intensityPlot(wvlRange=[1560.,1562.],linLog='lin')

# %%
c1.intensityList(wvlRange=[1560.,1565.])
# Out:
#  temperature =    1.58e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_1     1    11                 2p2 3P0.0 - 2s 2p3 3D1.0                 1560.3090     9.95e+03     6.77e+07 Y
#   c_1     2    12                 2p2 3P1.0 - 2s 2p3 3D2.0                 1560.6820     2.36e+04     9.13e+07 Y
#   c_1     2    11                 2p2 3P1.0 - 2s 2p3 3D1.0                 1560.7090     7.45e+03     5.07e+07 Y
#   c_1     3    12                 2p2 3P2.0 - 2s 2p3 3D2.0                 1561.3400     7.84e+03     3.03e+07 Y
#   c_1     3    11                 2p2 3P2.0 - 2s 2p3 3D1.0                 1561.3670     4.95e+02     3.37e+06 Y
#   c_1     3    13                 2p2 3P2.0 - 2s 2p3 3D3.0                 1561.4380     4.88e+04     1.21e+08 Y
#
#  ------------------------------------------

# %%
c1 = ch.ion('c_1',temperature=15848.0,eDensity=1.e+14,em=1.1*1.e+31)
c1.intensityList(wvlRange=[1560.,1565.])
# Out:
#  temperature =    1.58e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_1     1    11                 2p2 3P0.0 - 2s 2p3 3D1.0                 1560.3090     5.47e+03     6.77e+07 Y
#   c_1     2    12                 2p2 3P1.0 - 2s 2p3 3D2.0                 1560.6820     1.30e+04     9.13e+07 Y
#   c_1     2    11                 2p2 3P1.0 - 2s 2p3 3D1.0                 1560.7090     4.10e+03     5.07e+07 Y
#   c_1     3    12                 2p2 3P2.0 - 2s 2p3 3D2.0                 1561.3400     4.31e+03     3.03e+07 Y
#   c_1     3    11                 2p2 3P2.0 - 2s 2p3 3D1.0                 1561.3670     2.72e+02     3.37e+06 Y
#   c_1     3    13                 2p2 3P2.0 - 2s 2p3 3D3.0                 1561.4380     2.69e+04     1.21e+08 Y
#
#  ------------------------------------------

# %%
he2 = ch.ion('he_2',temperature=79432.8,eDensity=1.e+14,em=3.e+30)

# %%
he2.intensityPlot(wvlRange=[1639.,1641.],linLog='lin')

# %%
he2.intensityList(wvlRange=[1640.,1645.])
# Out:
#  temperature =    7.94e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  he_2     3     8                  2p 2P0.5 - 3d 2D1.5                     1640.3320     1.07e+05     8.63e+08 Y
#  he_2     2     7                  2s 2S0.5 - 3p 2P1.5                     1640.3450     3.08e+04     3.60e+08 Y
#  he_2     3     5                  2p 2P0.5 - 3s 2S0.5                     1640.3750     4.63e+04     3.37e+07 Y
#  he_2     2     6                  2s 2S0.5 - 3p 2P0.5                     1640.3910     1.54e+04     3.59e+08 Y
#  he_2     4     9                  2p 2P1.5 - 3d 2D2.5                     1640.4740     1.93e+05     1.04e+09 Y
#  he_2     4     8                  2p 2P1.5 - 3d 2D1.5                     1640.4900     2.14e+04     1.72e+08 Y
# ...

# %%
he2.intensityPlot(wvlRange=[1640.3,1640.6],linLog='lin')

# %%
he2 = ch.ion('he_2',temperature=79432.8,eDensity=1.e+14,em=1.e+30)
he2.intensityList(wvlRange=[1640.,1645.])
# Out:
#  temperature =    7.94e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  he_2     3     8                  2p 2P0.5 - 3d 2D1.5                     1640.3320     3.57e+04     8.63e+08 Y
#  he_2     2     7                  2s 2S0.5 - 3p 2P1.5                     1640.3450     1.03e+04     3.60e+08 Y
#  he_2     3     5                  2p 2P0.5 - 3s 2S0.5                     1640.3750     1.54e+04     3.37e+07 Y
#  he_2     2     6                  2s 2S0.5 - 3p 2P0.5                     1640.3910     5.12e+03     3.59e+08 Y
#  he_2     4     9                  2p 2P1.5 - 3d 2D2.5                     1640.4740     6.42e+04     1.04e+09 Y
#  he_2     4     8                  2p 2P1.5 - 3d 2D1.5                     1640.4900     7.15e+03     1.72e+08 Y
# ...

# %%
c1 = ch.ion('c_1',temperature=15848.0,eDensity=1.e+14,em=3.e+32)
c1.intensityPlot(wvlRange=[1650.,1670.],linLog='lin')

# %%
c1.intensityList(wvlRange=[1650.,1660.])
# Out:
#  temperature =    1.58e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_1     2     9                 2p2 3P1.0 - 2p 3s 3P2.0                  1656.2670     1.02e+05     8.84e+07 Y
#   c_1     1     8                 2p2 3P0.0 - 2p 3s 3P1.0                  1656.9290     8.13e+04     1.18e+08 Y
#   c_1     3     9                 2p2 3P2.0 - 2p 3s 3P2.0                  1657.0080     3.04e+05     2.64e+08 Y
#   c_1     2     8                 2p2 3P1.0 - 2p 3s 3P1.0                  1657.3800     6.05e+04     8.79e+07 Y
#   c_1     2     7                 2p2 3P1.0 - 2p 3s 3P0.0                  1657.9070     8.12e+04     3.52e+08 Y
#   c_1     3     8                 2p2 3P2.0 - 2p 3s 3P1.0                  1658.1220     1.01e+05     1.47e+08 Y
#
#  ------------------------------------------

# %%
c1 = ch.ion('c_1',temperature=15848.0,eDensity=1.e+14,em=1.5*1.e+32)
c1.intensityList(wvlRange=[1650.,1660.])
# Out:
#  temperature =    1.58e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_1     2     9                 2p2 3P1.0 - 2p 3s 3P2.0                  1656.2670     5.10e+04     8.84e+07 Y
#   c_1     1     8                 2p2 3P0.0 - 2p 3s 3P1.0                  1656.9290     4.07e+04     1.18e+08 Y
#   c_1     3     9                 2p2 3P2.0 - 2p 3s 3P2.0                  1657.0080     1.52e+05     2.64e+08 Y
#   c_1     2     8                 2p2 3P1.0 - 2p 3s 3P1.0                  1657.3800     3.03e+04     8.79e+07 Y
#   c_1     2     7                 2p2 3P1.0 - 2p 3s 3P0.0                  1657.9070     4.06e+04     3.52e+08 Y
#   c_1     3     8                 2p2 3P2.0 - 2p 3s 3P1.0                  1658.1220     5.06e+04     1.47e+08 Y
#
#  ------------------------------------------

# %%
al2=ch.ion('al_2',temperature=31622.77,eDensity=1.e+14,em=1.5*1.e+30)
al2.intensityPlot(wvlRange=[1660.,1680.],linLog='lin')

# %%
al2.intensityList(wvlRange=[1600.,1700.])
# Out:
#  temperature =    3.16e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  al_2     7    57               3s 4s 3S1.0 - 3p 3d 3P0.0                  1617.7840     3.95e-02     6.38e+06 N
#  al_2     7    56               3s 4s 3S1.0 - 3p 3d 3P1.0                  1619.0580     1.13e-01     6.00e+06 N
#  al_2     7    55               3s 4s 3S1.0 - 3p 3d 3P2.0                  1620.8140     1.98e-01     6.25e+06 N
#  al_2     5    25               3s 3p 1P1.0 - 3s 5s 1S0.0                  1625.6280     2.87e+01     6.75e+07 Y
#  al_2     6    52                 3p2 1D2.0 - 3p 4s 3P1.0                  1656.9090     1.17e-02     1.99e+05 Y
#  al_2     1     5                 3s2 1S0.0 - 3s 3p 1P1.0                  1670.7870     5.43e+04     1.53e+09 Y
# ...

# %%
fe2=ch.ion('fe_2',temperature=31622.77,eDensity=1.e+14,em=5.e+31)
fe2.intensityPlot(wvlRange=[1710.,1720.],linLog='lin')

# %%
fe2.intensityPlot(wvlRange=[1700.,1720.],linLog='lin')

# %%
fe2.intensityList(wvlRange=[1710.,1720.])
# Out:
#  temperature =    3.16e+04 eDensity =   1.00e+14
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  fe_2    10   101          3d6(5D).4s 4D3.5 - 3d6(3G).4p 4F3.5             1711.6840     4.25e+01     1.06e+06 Y
#  fe_2     7    73                 3d7 4F3.5 - 3d6(3H).4p 4G4.5             1713.0000     1.19e+04     1.42e+08 Y
#  fe_2    15   113                 3d7 4P1.5 - 3d6(3D).4p 4P1.5             1713.2140     2.72e+02     1.55e+07 Y
#  fe_2    16   114                 3d7 4P0.5 - 3d6(3D).4p 4P0.5             1715.0260     1.67e+02     1.93e+07 Y
#  fe_2    15   112                 3d7 4P1.5 - 3d6(3D).4p 4P2.5             1715.5150     9.09e+02     3.47e+07 Y
#  fe_2    11   103          3d6(5D).4s 4D2.5 - 3d6(3G).4p 4F1.5             1717.6020     2.92e+00     1.48e+05 Y
# ...

# %%
si2=ch.ion('si_2',temperature=31622.77,eDensity=1.e+13,em=7.e+30)
si2.intensityPlot(wvlRange=[1800.,1820.],linLog='lin')

# %%
si2.intensityList(wvlRange=[1800.,1820.])
# Out:
#  temperature =    3.16e+04 eDensity =   1.00e+13
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  si_2     1     6              3s2.3p 2P0.5 - 3s.3p2 2D1.5                 1808.0130     1.08e+05     2.55e+06 Y
#  si_2     2     7              3s2.3p 2P1.5 - 3s.3p2 2D2.5                 1816.9280     1.74e+05     2.65e+06 Y
#  si_2     2     6              3s2.3p 2P1.5 - 3s.3p2 2D1.5                 1817.4510     1.44e+04     3.43e+05 Y
#
#  ------------------------------------------

# %% [markdown]
# # PLAGUE

# %%
si2 = ch.ion('si_2',temperature=31622.8,eDensity=1.e+11,em=5.e+29)
si2.intensityPlot(wvlRange=[1520.,1540.],linLog='lin')
si2.intensityList(wvlRange=[1520.,1540.])
# Out:
#  temperature =    3.16e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  si_2     1     8              3s2.3p 2P0.5 - 3s2.4s 2S0.5                 1526.7070     1.77e+03     3.82e+08 Y
#  si_2     2     8              3s2.3p 2P1.5 - 3s2.4s 2S0.5                 1533.4310     3.49e+03     7.54e+08 Y
#
#  ------------------------------------------

# %%
c4 = ch.ion('c_4',temperature=1.e+5,eDensity=1.e+11,em=3.e+27)
c4.intensityPlot(wvlRange=[1540.,1600.],linLog='lin')
c4.intensityList(wvlRange=[1540.,1560.])
# Out:
#  temperature =    1.00e+05 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_4    95   150        1s.2s(1S).3p 2P1.5 - 1s.2s(3S).4s 2S0.5           1540.6230     1.18e-19     1.62e+07 N
#   c_4   209   498        1s.2p(3P).4p 4P0.5 - 1s.2p(3P).6d 4D1.5           1544.7990     1.21e-20     6.57e+07 N
#   c_4   209   497        1s.2p(3P).4p 4P0.5 - 1s.2p(3P).6d 4D0.5           1544.9970     1.68e-20     1.17e+08 N
#   c_4   216   570        1s.2p(3P).4d 2D1.5 - 1s.2p(3P).6f 2D1.5           1545.2990     5.82e-20     4.12e+07 N
#   c_4   211   500        1s.2p(3P).4p 4P2.5 - 1s.2p(3P).6d 4D3.5           1545.7440     1.13e-19     1.32e+08 N
#   c_4   217   569        1s.2p(3P).4d 2D2.5 - 1s.2p(3P).6f 2D2.5           1547.2590     1.15e-19     4.64e+07 N
# ...

# %%
c1 = ch.ion('c_1',temperature=15848.0,eDensity=1.e+11,em=1.2*1.e+30)
c1.intensityPlot(wvlRange=[1560.,1562.],linLog='lin')
c1.intensityList(wvlRange=[1560.,1565.])
# Out:
#  temperature =    1.58e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_1     1    11                 2p2 3P0.0 - 2s 2p3 3D1.0                 1560.3090     6.27e+02     6.77e+07 Y
#   c_1     2    12                 2p2 3P1.0 - 2s 2p3 3D2.0                 1560.6820     1.49e+03     9.13e+07 Y
#   c_1     2    11                 2p2 3P1.0 - 2s 2p3 3D1.0                 1560.7090     4.70e+02     5.07e+07 Y
#   c_1     3    12                 2p2 3P2.0 - 2s 2p3 3D2.0                 1561.3400     4.95e+02     3.03e+07 Y
#   c_1     3    11                 2p2 3P2.0 - 2s 2p3 3D1.0                 1561.3670     3.12e+01     3.37e+06 Y
#   c_1     3    13                 2p2 3P2.0 - 2s 2p3 3D3.0                 1561.4380     3.10e+03     1.21e+08 Y
#
#  ------------------------------------------

# %%
c1 = ch.ion('c_1',temperature=15848.0,eDensity=1.e+11,em=6.e+29)
c1.intensityList(wvlRange=[1560.,1565.])
# Out:
#  temperature =    1.58e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_1     1    11                 2p2 3P0.0 - 2s 2p3 3D1.0                 1560.3090     3.14e+02     6.77e+07 Y
#   c_1     2    12                 2p2 3P1.0 - 2s 2p3 3D2.0                 1560.6820     7.46e+02     9.13e+07 Y
#   c_1     2    11                 2p2 3P1.0 - 2s 2p3 3D1.0                 1560.7090     2.35e+02     5.07e+07 Y
#   c_1     3    12                 2p2 3P2.0 - 2s 2p3 3D2.0                 1561.3400     2.48e+02     3.03e+07 Y
#   c_1     3    11                 2p2 3P2.0 - 2s 2p3 3D1.0                 1561.3670     1.56e+01     3.37e+06 Y
#   c_1     3    13                 2p2 3P2.0 - 2s 2p3 3D3.0                 1561.4380     1.55e+03     1.21e+08 Y
#
#  ------------------------------------------

# %%
he2 = ch.ion('he_2',temperature=79432.8,eDensity=1.e+11,em=2.e+29)
he2.intensityPlot(wvlRange=[1639.,1641.],linLog='lin')
he2.intensityList(wvlRange=[1640.,1645.])
# Out:
#  temperature =    7.94e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  he_2     3     8                  2p 2P0.5 - 3d 2D1.5                     1640.3320     6.38e+03     8.63e+08 Y
#  he_2     2     7                  2s 2S0.5 - 3p 2P1.5                     1640.3450     1.88e+03     3.60e+08 Y
#  he_2     3     5                  2p 2P0.5 - 3s 2S0.5                     1640.3750     2.88e+03     3.37e+07 Y
#  he_2     2     6                  2s 2S0.5 - 3p 2P0.5                     1640.3910     9.40e+02     3.59e+08 Y
#  he_2     4     9                  2p 2P1.5 - 3d 2D2.5                     1640.4740     1.15e+04     1.04e+09 Y
#  he_2     4     8                  2p 2P1.5 - 3d 2D1.5                     1640.4900     1.28e+03     1.72e+08 Y
# ...

# %%
he2 = ch.ion('he_2',temperature=79432.8,eDensity=1.e+11,em=6.5e+28)
he2.intensityList(wvlRange=[1640.,1645.])
# Out:
#  temperature =    7.94e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  he_2     3     8                  2p 2P0.5 - 3d 2D1.5                     1640.3320     2.07e+03     8.63e+08 Y
#  he_2     2     7                  2s 2S0.5 - 3p 2P1.5                     1640.3450     6.12e+02     3.60e+08 Y
#  he_2     3     5                  2p 2P0.5 - 3s 2S0.5                     1640.3750     9.36e+02     3.37e+07 Y
#  he_2     2     6                  2s 2S0.5 - 3p 2P0.5                     1640.3910     3.06e+02     3.59e+08 Y
#  he_2     4     9                  2p 2P1.5 - 3d 2D2.5                     1640.4740     3.73e+03     1.04e+09 Y
#  he_2     4     8                  2p 2P1.5 - 3d 2D1.5                     1640.4900     4.15e+02     1.72e+08 Y
# ...

# %%
c1 = ch.ion('c_1',temperature=15848.0,eDensity=1.e+11,em=1.e+31)
c1.intensityPlot(wvlRange=[1650.,1670.],linLog='lin')
c1.intensityList(wvlRange=[1650.,1660.])
# Out:
#  temperature =    1.58e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_1     2     9                 2p2 3P1.0 - 2p 3s 3P2.0                  1656.2670     3.75e+03     8.84e+07 Y
#   c_1     1     8                 2p2 3P0.0 - 2p 3s 3P1.0                  1656.9290     2.99e+03     1.18e+08 Y
#   c_1     3     9                 2p2 3P2.0 - 2p 3s 3P2.0                  1657.0080     1.12e+04     2.64e+08 Y
#   c_1     2     8                 2p2 3P1.0 - 2p 3s 3P1.0                  1657.3800     2.23e+03     8.79e+07 Y
#   c_1     2     7                 2p2 3P1.0 - 2p 3s 3P0.0                  1657.9070     2.99e+03     3.52e+08 Y
#   c_1     3     8                 2p2 3P2.0 - 2p 3s 3P1.0                  1658.1220     3.72e+03     1.47e+08 Y
#
#  ------------------------------------------

# %%
c1 = ch.ion('c_1',temperature=15848.0,eDensity=1.e+11,em=3.5e+30)
c1.intensityList(wvlRange=[1650.,1660.])
# Out:
#  temperature =    1.58e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#   c_1     2     9                 2p2 3P1.0 - 2p 3s 3P2.0                  1656.2670     1.31e+03     8.84e+07 Y
#   c_1     1     8                 2p2 3P0.0 - 2p 3s 3P1.0                  1656.9290     1.05e+03     1.18e+08 Y
#   c_1     3     9                 2p2 3P2.0 - 2p 3s 3P2.0                  1657.0080     3.92e+03     2.64e+08 Y
#   c_1     2     8                 2p2 3P1.0 - 2p 3s 3P1.0                  1657.3800     7.79e+02     8.79e+07 Y
#   c_1     2     7                 2p2 3P1.0 - 2p 3s 3P0.0                  1657.9070     1.05e+03     3.52e+08 Y
#   c_1     3     8                 2p2 3P2.0 - 2p 3s 3P1.0                  1658.1220     1.30e+03     1.47e+08 Y
#
#  ------------------------------------------

# %%
al2=ch.ion('al_2',temperature=31622.77,eDensity=1.e+11,em=1.e+29)
al2.intensityPlot(wvlRange=[1660.,1680.],linLog='lin')
al2.intensityList(wvlRange=[1600.,1700.])
# Out:
#  temperature =    3.16e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  al_2     7    57               3s 4s 3S1.0 - 3p 3d 3P0.0                  1617.7840     1.31e-03     6.38e+06 N
#  al_2     7    56               3s 4s 3S1.0 - 3p 3d 3P1.0                  1619.0580     3.73e-03     6.00e+06 N
#  al_2     7    55               3s 4s 3S1.0 - 3p 3d 3P2.0                  1620.8140     6.65e-03     6.25e+06 N
#  al_2     5    25               3s 3p 1P1.0 - 3s 5s 1S0.0                  1625.6280     3.31e+00     6.75e+07 Y
#  al_2     6    52                 3p2 1D2.0 - 3p 4s 3P1.0                  1656.9090     4.79e-04     1.99e+05 Y
#  al_2     1     5                 3s2 1S0.0 - 3s 3p 1P1.0                  1670.7870     4.09e+03     1.53e+09 Y
# ...

# %%
fe2=ch.ion('fe_2',temperature=31622.77,eDensity=1.e+11,em=8.e+30)
fe2.intensityPlot(wvlRange=[1710.,1720.],linLog='lin')
fe2.intensityList(wvlRange=[1710.,1720.])
# Out:
#  temperature =    3.16e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  fe_2    10   101          3d6(5D).4s 4D3.5 - 3d6(3G).4p 4F3.5             1711.6840     7.01e+00     1.06e+06 Y
#  fe_2     7    73                 3d7 4F3.5 - 3d6(3H).4p 4G4.5             1713.0000     1.99e+03     1.42e+08 Y
#  fe_2    15   113                 3d7 4P1.5 - 3d6(3D).4p 4P1.5             1713.2140     4.47e+01     1.55e+07 Y
#  fe_2    16   114                 3d7 4P0.5 - 3d6(3D).4p 4P0.5             1715.0260     2.74e+01     1.93e+07 Y
#  fe_2    15   112                 3d7 4P1.5 - 3d6(3D).4p 4P2.5             1715.5150     1.49e+02     3.47e+07 Y
#  fe_2    11   103          3d6(5D).4s 4D2.5 - 3d6(3G).4p 4F1.5             1717.6020     4.82e-01     1.48e+05 Y
# ...

# %%
si2=ch.ion('si_2',temperature=31622.77,eDensity=1.e+11,em=1.e+30)
si2.intensityPlot(wvlRange=[1800.,1820.],linLog='lin')
si2.intensityList(wvlRange=[1800.,1820.])
# Out:
#  temperature =    3.16e+04 eDensity =   1.00e+11
#
#  ------------------------------------------
#
#   Ion  lvl1  lvl2                     lower - upper                           Wvl(A)    Intensity      A value Obs
#  si_2     1     6              3s2.3p 2P0.5 - 3s.3p2 2D1.5                 1808.0130     2.33e+04     2.55e+06 Y
#  si_2     2     7              3s2.3p 2P1.5 - 3s.3p2 2D2.5                 1816.9280     3.93e+04     2.65e+06 Y
#  si_2     2     6              3s2.3p 2P1.5 - 3s.3p2 2D1.5                 1817.4510     3.12e+03     3.43e+05 Y
#
#  ------------------------------------------

# %%
import pandas as pd

# %%
var = pd.read_excel("skylab_so82b_calib_681.xlsx")

# %%
x = list(var['lamb'])

# %%
y = list(var['logiflare'])
y2=list(var['logiplage '])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_47145/3971998729.py in <module>
# ----> 1 y = list(var['logiflare'])
#       2 y2=list(var['logiplage '])
#
# NameError: name 'var' is not defined

# %%
N=np.log10(si2.Spectrum['intensity'])

# %%
var2 = pd.read_excel("skylab_so82b_calib_681_linear.xlsx")

# %%
x = list(var2['lamb'])
y = list(var2['plage'])
y2=list(var2['flare'])

# %% [markdown]
# # Continuum flare

# %%
plt.figure(figsize=(15,5))
plt.plot(x,y2)
#plt.scatter(x,y,marker="*",s=0.1)
plt.xlabel('Wavelength(Å)')
plt.title("Flare Spectrum S082B")
plt.show()

# %%
wvl=1520. + 0.035*np.arange(500)
si2.spectrum(wvl,filter=(chfilters.gaussian,0.15),label='default')
si2.spectrum(wvl,filter=(chfilters.boxcar,1),label='.8')
#si2.spectrum(wvl,filter=(chfilters.boxcar,0.60),label='.6')
#si2.spectrum(wvl,filter=(chfilters.boxcar,0.40),label='.4')
#si2.spectrum(wvl,filter=(chfilters.boxcar,0.20),label='.2')

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y2,label='Skylab')
#plt.scatter(x,y,marker="*",s=0.1)
plt.title("Si II 1526 Å, 1533 Å")
#plt.plot(wvl, si2.Spectrum['.4']['intensity'])
#plt.plot(wvl, si2.Spectrum['.2']['intensity'])
#plt.plot(wvl, si2.Spectrum['.6']['intensity'])
plt.plot(wvl, si2.Spectrum['default']['intensity'],label='CHIANTI')
plt.xlim([1520,1540])
plt.ylim([0,100000])
plt.xlabel(si2.Spectrum['default']['xlabel'])
plt.ylabel(si2.Spectrum['default']['ylabel'])
plt.legend(loc='upper left')
plt.savefig('Si_II_1500.jpg')
plt.show()

# %%
si2.intensity(0)

# %%
np.max(si2.Spectrum['.8']['intensity'])
# Out:
# 19684.870644585022

# %%
wvl2=1540. + 0.035*np.arange(600)

# %%
#c4.spectrum(wvl2,filter=(chfilters.boxcar,1))
c4.spectrum(wvl2,filter=(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y2,label='Skylab')
plt.plot(wvl2, c4.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1540,1560])
plt.ylim([0,350000])
plt.xlabel(c4.Spectrum['xlabel'])
plt.ylabel(c4.Spectrum['ylabel'])
plt.title("C IV 1548 Å, 1550 Å")
plt.legend(loc='upper left')
plt.savefig('C_IV_1550.jpg')
plt.show()

# %%
np.max(c4.Spectrum['intensity'])
# Out:
# 323136.04371212714

# %%
wvl3=1555. + 0.035*np.arange(300)
#c1.spectrum(wvl3,filter=(chfilters.boxcar,1))
c1.spectrum(wvl3,filter=(chfilters.gaussian,.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y2,label='Skylab')
plt.plot(wvl3, c1.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1558,1565])
plt.ylim([0,125000])
plt.xlabel(c4.Spectrum['xlabel'])
plt.ylabel(c4.Spectrum['ylabel'])
plt.title("C I 1560 Å")
plt.legend(loc='upper left')
plt.savefig('C_I_1560.jpg')
plt.show()

# %%
wvl4=1639. + 0.035*np.arange(80)

# %%
#he2.spectrum(wvl4,filter=(chfilters.boxcar,1))
he2.spectrum(wvl4,filter=(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y2,label='Skylab')
plt.plot(wvl4,he2.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1639,1642])
plt.ylim([0,600000])
plt.xlabel(he2.Spectrum['xlabel'])
plt.ylabel(he2.Spectrum['ylabel'])
plt.title("He II 1640 Å")
plt.legend(loc='upper left')
plt.savefig('He_II_1640.jpg')
plt.show()

# %%
wvl5=1650. + 0.035*np.arange(300)
#c1.spectrum(wvl5,filter=(chfilters.boxcar,1))
c1.spectrum(wvl5,(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y2,label='Skylab')
plt.plot(wvl5, c1.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1652,1662])
plt.ylim([0,510000])
plt.xlabel(c1.Spectrum['xlabel'])
plt.ylabel(c1.Spectrum['ylabel'])
plt.title("CI 1656 Å ")
plt.legend(loc='upper left')
plt.savefig('C_I_1656.jpg')
plt.show()

# %%
wvl6=1665.+ 0.035*np.arange(300)
#al2.spectrum(wvl6,(chfilters.boxcar,1))
al2.spectrum(wvl6,(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y2,label='Skylab')
plt.plot(wvl6, al2.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1667,1677])
plt.ylim([0,200000])
plt.xlabel(al2.Spectrum['xlabel'])
plt.ylabel(al2.Spectrum['ylabel'])
plt.title("Al II 1670 Å ")
plt.legend(loc='upper left')
plt.savefig('Al_II_1670.jpg')
plt.show()

# %%
wvl7=1710.+ 0.035*np.arange(275)
fe2.spectrum(wvl7,(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y2,label='Skylab')
plt.plot(wvl7, fe2.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1710,1716])
plt.ylim([0,80000])
plt.xlabel(al2.Spectrum['xlabel'])
plt.ylabel(al2.Spectrum['ylabel'])
plt.title("Fe II 1713 Å ")
plt.legend(loc='upper left')
plt.savefig('Fe_II_1713.jpg')
plt.show()

# %%
wvl8=1805.+ 0.035*np.arange(450)
si2.spectrum(wvl8,filter=(chfilters.gaussian,0.15))
#si2.spectrum(wvl8,filter=(chfilters.boxcar,1))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y2,label='Skylab')
plt.plot(wvl8,si2.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1800,1820])
plt.ylim([0,600000])
plt.xlabel(si2.Spectrum['xlabel'])
plt.ylabel(si2.Spectrum['ylabel'])
plt.title("Si II 1808 Å,1816 Å")
plt.legend(loc='upper left')
plt.savefig('Si_II_1816.jpg')
plt.show()

# %% [markdown]
# # Continuum Plage

# %%
plt.figure(figsize=(15,5))
plt.plot(x,y)
#plt.scatter(x,y,marker="*",s=0.1)
plt.xlabel('Wavelength(Å)')
plt.title("Plage Spectrum S082B")
plt.show()

# %%
wvl=1520. + 0.035*np.arange(500)
si2.spectrum(wvl,filter=(chfilters.gaussian,0.15),label='default')
si2.spectrum(wvl,filter=(chfilters.boxcar,1),label='.8')
#si2.spectrum(wvl,filter=(chfilters.boxcar,0.60),label='.6')
#si2.spectrum(wvl,filter=(chfilters.boxcar,0.40),label='.4')
#si2.spectrum(wvl,filter=(chfilters.boxcar,0.20),label='.2')

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y,label='Skylab')
#plt.scatter(x,y,marker="*",s=0.1)
plt.title("Si II 1526 Å, 1533 Å")
#plt.plot(wvl, si2.Spectrum['.4']['intensity'])
#plt.plot(wvl, si2.Spectrum['.2']['intensity'])
#plt.plot(wvl, si2.Spectrum['.6']['intensity'])
plt.plot(wvl, si2.Spectrum['default']['intensity'],label='CHIANTI')
plt.xlim([1520,1540])
plt.ylim([0,15000])
plt.xlabel(si2.Spectrum['default']['xlabel'])
plt.ylabel(si2.Spectrum['default']['ylabel'])
plt.legend(loc='upper left')
plt.savefig('Si_II_1500_P.jpg')
plt.show()

# %%
wvl2=1540. + 0.035*np.arange(600)
#c4.spectrum(wvl2,filter=(chfilters.boxcar,1))
c4.spectrum(wvl2,filter=(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y,label='Skylab')
plt.plot(wvl2, c4.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1540,1560])
plt.ylim([0,32000])
plt.xlabel(c4.Spectrum['xlabel'])
plt.ylabel(c4.Spectrum['ylabel'])
plt.title("C IV 1548 Å, 1550 Å")
plt.legend(loc='upper left')
plt.savefig('C_IV_1550_P.jpg')
plt.show()

# %%
wvl3=1555. + 0.035*np.arange(300)
#c1.spectrum(wvl3,filter=(chfilters.boxcar,1))
c1.spectrum(wvl3,filter=(chfilters.gaussian,.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y,label='Skylab')
plt.plot(wvl3, c1.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1558,1565])
plt.ylim([0,5000])
plt.xlabel(c4.Spectrum['xlabel'])
plt.ylabel(c4.Spectrum['ylabel'])
plt.title("C I 1560 Å")
plt.legend(loc='upper left')
plt.savefig('C_I_1560_P.jpg')
plt.show()

# %%
wvl4=1639. + 0.035*np.arange(80)
he2.spectrum(wvl4,filter=(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y,label='Skylab')
plt.plot(wvl4,he2.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1639,1642])
plt.ylim([0,40000])
plt.xlabel(he2.Spectrum['xlabel'])
plt.ylabel(he2.Spectrum['ylabel'])
plt.title("He II 1640 Å")
plt.legend(loc='upper left')
plt.savefig('He_II_1640_P.jpg')
plt.show()

# %%
wvl5=1650. + 0.035*np.arange(300)
#c1.spectrum(wvl5,filter=(chfilters.boxcar,1))
c1.spectrum(wvl5,(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y,label='Skylab')
plt.plot(wvl5, c1.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1655,1660])
plt.ylim([0,20000])
plt.xlabel(c1.Spectrum['xlabel'])
plt.ylabel(c1.Spectrum['ylabel'])
plt.title("C I 1656 Å ")
plt.legend(loc='upper left')
plt.savefig('C_I_1656_P.jpg')
plt.show()

# %%
wvl6=1665.+ 0.035*np.arange(300)
#al2.spectrum(wvl6,(chfilters.boxcar,1))
al2.spectrum(wvl6,(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y,label='Skylab')
plt.plot(wvl6, al2.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1660,1680])
plt.ylim([0,20000])
plt.xlabel(al2.Spectrum['xlabel'])
plt.ylabel(al2.Spectrum['ylabel'])
plt.title("Al II 1670 Å ")
plt.legend(loc='upper left')
plt.savefig('Al_II_1670_P.jpg')
plt.show()

# %%
wvl7=1710.+ 0.035*np.arange(275)
fe2.spectrum(wvl7,(chfilters.gaussian,0.15))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y,label='Skylab')
plt.plot(wvl7, fe2.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1710,1716])
plt.ylim([0,20000])
plt.xlabel(al2.Spectrum['xlabel'])
plt.ylabel(al2.Spectrum['ylabel'])
plt.title("Fe II 1713 Å ")
plt.legend(loc='upper left')
plt.savefig('Fe_II_1713_P.jpg')
plt.show()

# %%
wvl8=1805.+ 0.035*np.arange(450)
si2.spectrum(wvl8,filter=(chfilters.gaussian,0.15))
#si2.spectrum(wvl8,filter=(chfilters.boxcar,1))

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y,label='Skylab')
plt.plot(wvl8,si2.Spectrum['intensity'],label='CHIANTI')
plt.xlim([1800,1820])
plt.ylim([0,200000])
plt.xlabel(si2.Spectrum['xlabel'])
plt.ylabel(si2.Spectrum['ylabel'])
plt.title("Si II 1808 Å,1816 Å")
plt.legend(loc='upper left')
plt.savefig('Si_II_1816_P.jpg')
plt.show()

# %%
from scipy import integrate

# %%
integrate.simps(si2.Spectrum['intensity'],wvl8)
# Out:
# 65719.42257555938

# %%
(wvl8,si2.Spectrum['intensity'])

# %%
integrate.simps
# Out:
# <function scipy.integrate._quadrature.simps(y, x=None, dx=1.0, axis=-1, even='avg')>

# %%
wvl6, al2.Spectrum['intensity']

# %%
integrate.simps(al2.Spectrum['intensity'],wvl6)
# Out:
# 4094.2881055527487
